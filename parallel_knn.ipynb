# %%
from matplotlib import pyplot as plt

# %%
nw = [1,2,4,8,16,32,64,128,256]
# input30k.csv
stl = [357.669,179.388,94.594,47.408,23.671,11.884,6.071,4.415,3.849]
ff = [356.89,188.304,94.537,47.208,23.667,11.855,6.037,4.466,3.769]
ideal = [356.409,178.254,89.177,44.638,22.369,11.234,5.667,2.88,1.491]

# %%
plt.plot(nw, stl, label='STL')
plt.plot(nw, ff, label='FF')
plt.plot(nw, ideal, label='Ideal')
plt.xlabel("Number of workers (nw)")
plt.ylabel("Time (seconds)")
plt.legend()
plt.savefig('timings30k.png')

# %%
plt.plot(nw[5:], stl[5:], label='STL')
plt.plot(nw[5:], ff[5:], label='FF')
plt.plot(nw[5:], ideal[5:], label='Ideal')
plt.xticks(nw[5:])
plt.xlabel("Number of workers (nw)")
plt.ylabel("Time (seconds)")
plt.legend()
plt.savefig('timings30k_partial.png')

# %%
scalab = [1,1.99382901866346,3.78109605260376,7.54448616267297,15.1100080266993,30.0966846179737,58.914346895075,81.0122310305776,92.925175370226]
speedup = [0.996217172860941,1.98628670814101,3.76679281984058,7.51594667566655,15.0528494782645,29.9828340626052,58.6914841047603,80.7057757644394,92.5736554949337]
efficiency = [0.996477189803981,0.99367850692354,0.942734211472187,0.941571042861964,0.944995986650332,0.945304611242006,0.933454126173612,0.652321630804077,0.387373343725643]
# efficiency = [0.00416865873195608,0.00831159274867884,0.0157620990760513,0.0314503881201485,0.0629884669004267,0.125462807135645,0.245593806621644,0.337712344280861,0.387373343725643]
ideal_eff = [1,1,1,1,1,1,1,1,1]

# %%
plt.plot(nw, scalab, label='Scalab')
plt.plot(nw, speedup, label='Speedup')
plt.xlabel("Number of workers (nw)")
plt.legend()
plt.savefig('scalab_speedup.png')

# %%
plt.plot(nw, efficiency, label='Efficiency')
plt.plot(nw, ideal_eff, label='Ideal')
plt.xlabel("Number of workers (nw)")
plt.xticks(nw[4:])
plt.legend()
plt.savefig('efficiency.png')
